# %%
import numpy as np
import math, copy
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# plt.style.use('./deeplearning.mplstyle')
# from lab_utils_uni import plt_house_x, plt_contour_wgrad, plt_divergence, plt_gradients

# %%
#input data from file
data = np.loadtxt('data.txt', delimiter=',')
print(data.shape)
# Out:
# (49, 3)

# %%
xTrain = data[:,0]
yTrain = data[:,2]
#print(len(xTrain))
plt.figure('Abhinav')
plt.scatter(xTrain, yTrain)

plt.show()

# %%
xTrain.shape, yTrain.shape
# Out:
# ((49,), (49,))

# %%
def computeCost(x, y, w, b):
    m = len(y)
    J = 0
    h = x*w + b
    # print(x)
    J = np.sum((h-y)**2)/(2*m)
    return J

# %%
# n = len(xTrain)
# w = 0
# b = 0
# c = computeCost(xTrain, yTrain, w, b)
print(len(yTrain))
# Out:
# 49

# %%
def computeGradient(x, y, w, b):
    m = len(y)
    h = x*w + b
    dw = np.sum(np.dot(x, (h-y)))/m
    db = np.sum(h-y)/m
    # print(h, dw, db)
    return dw, db

# %%
#print(dw)

# %%
def gradient_descent(x, y, w, b, alpha, num_iters):
    m = len(y)
    J_history = []
    for i in range(num_iters):
        # print('hi')
        J_history.append(computeCost(x, y, w, b))
        dw, db = computeGradient(x, y, w, b)
        # print(dw,db)
        w = w - alpha*dw
        b = b - alpha*dw
    return w, b, J_history

# %%
w_init = 0
b_init = 0
it = 1000
alpha = 0.000000001
w, b, J_history = gradient_descent(xTrain, yTrain, w_init, b_init, alpha, it)
print(w, b)
plt.plot(J_history)
plt.show()
# Out:
# 1.646452443072881 1.646452443072881

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12,4))
ax1.plot(J_history[:100])
ax2.plot(1000 + np.arange(len(J_history[1000:])), J_history[1000:])
ax1.set_title("Cost vs. iteration(start)");  ax2.set_title("Cost vs. iteration (end)")
ax1.set_ylabel('Cost')            ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')  ;  ax2.set_xlabel('iteration step') 
plt.show()

# %%
def reg_line(w,b):
    x = np.linspace(0, 5000, 1000000)
    y = w*x + b
    return x, y

# %%
xTrain = data[:,0]
yTrain = data[:,2]
regx, regy = reg_line(1.646452, 1.646452)
print(xTrain)
#print(len(xTrain))
plt.figure('Abhinav')
plt.scatter(xTrain, yTrain)
plt.plot(regx, regy, 'r')
plt.show()
# Out:
# [2104. 2104. 2104. 1600. 2400. 1416. 3000. 1985. 1534. 1427. 1380. 1494.
#  1940. 2000. 1890. 4478. 1268. 2300. 1320. 1236. 2609. 3031. 1767. 1888.
#  1604. 1962. 3890. 1100. 1458. 2526. 2200. 2637. 1839. 1000. 2040. 3137.
#  1811. 1437. 1239. 2132. 4215. 2162. 1664. 2238. 2567. 1200.  852. 1852.
#  1203.]
